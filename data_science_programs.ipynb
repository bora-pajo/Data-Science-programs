# %%
import csv as csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pylab as P
# %matplotlib inline

# %%
data = pd.read_csv('data_science.csv')

# %%
data.head(2)
# Out:
#               SCHOOL                                            PROGRAM  \
# 0  Auburn University  Online Master of Business Administration with ...
# 1  Auburn University                                       Data Science
#
#   DEGREE ONLINE ONCAMPUS COUNTRY STATE    CITY  \
# 0      M      F        T      US    AL  Auburn
# 1      B      F        T      US    AL  Auburn
#
#                                DEPARTMENT  \
# 0  Raymond J. Harbert College of Business
# 1                                Business
#
#                                                  URL
# 0  http://harbert.auburn.edu/academics/online-pro...
# 1  http://harbert.auburn.edu/academics/undergradu...

# %%
DegreeType = data['DEGREE'].value_counts()
DegreePlot = DegreeType.plot(kind='bar', color = 'orange')
DegreePlot.set_xlabel('M = Masters, B = Bachelors, C = Certificate, D = Doctorate')
DegreePlot.set_title('Frequency')

# %%
data.shape
# Out:
# (551, 10)

# %%
kind = data['ONLINE'].value_counts()
plot = kind.plot (kind = 'bar', color = 'red')
plot.set_xlabel('F = Not online, T = Online')
plot.set_title('Frequency')

# %%
Bachelor = len(data[data['DEGREE']=='B'])
print Bachelor
# Out:
# 49

# %%
Bach = data[data['DEGREE'] =='B']
Bach = pd.DataFrame(Bach)

# %%
Bach.head(2)
# Out:
#                      SCHOOL                  PROGRAM DEGREE ONLINE ONCAMPUS  \
# 1         Auburn University             Data Science      B      F        T
# 6  Arkansas Tech University  Business Data Analytics      B      F        T
#
#   COUNTRY STATE          CITY DEPARTMENT  \
# 1      US    AL        Auburn   Business
# 6      US    AR  Russellville   Business
#
#                                                  URL
# 1  http://harbert.auburn.edu/academics/undergradu...
# 6  http://www.atu.edu/business/programs_bdanalyti...

# %%
Bach.shape
# Out:
# (49, 10)

# %%
kind = Bach['SCHOOL'].value_counts()[:20]
plot = kind.plot (kind = 'barh', color = 'red')
#plot.set_xlabel('F = Not online, T = Online')
plot.set_title('Frequency')

# %%
kind = Bach['STATE'].value_counts()
plot = kind.plot (kind = 'barh', color = 'red')
#plot.set_xlabel('F = Not online, T = Online')
plot.set_title('Frequency')

# %%
kind = Bach['DEPARTMENT'].value_counts()
plot = kind.plot (kind = 'barh', color = 'red')
#plot.set_xlabel('F = Not online, T = Online')
plot.set_title('Frequency')

# %%
kind = Bach['PROGRAM'].value_counts()
plot = kind.plot (kind = 'barh', color = 'red')
#plot.set_xlabel('F = Not online, T = Online')
plot.set_title('Frequency')

# %%
kind = Bach['COUNTRY'].value_counts()
plot = kind.plot (kind = 'barh', color = 'blue')
#plot.set_xlabel
plot.set_title('Frequency')

# %%
Bach.head(1)
# Out:
#               SCHOOL       PROGRAM DEGREE ONLINE ONCAMPUS COUNTRY STATE  \
# 1  Auburn University  Data Science      B      F        T      US    AL
#
#      CITY DEPARTMENT                                                URL
# 1  Auburn   Business  http://harbert.auburn.edu/academics/undergradu...

# %%
import os
os.getcwd()
# Out:
# '/Users/bpajo/Documents/new_coder'

# %%
Bach['PROGRAM'].count()
# Out:
# 49

# %%
Bach['PROGRAM'].value_counts()[:49].plot(kind='barh')

# %%
Masters = len(data[data['DEGREE']=='M'])
print Masters
# Out:
# 390

# %%
Masters = data[data['DEGREE'] =='M']
Masters = pd.DataFrame(Masters)

# %%
Masters['SCHOOL']
# Out:
# 0                                     Auburn University
# 2                             The University of Alabama
# 3                             The University of Alabama
# 4                             The University of Alabama
# 5                             The University of Alabama
# 8                                University of Arkansas
# 9                                University of Arkansas
# 10                University of Arkansas at Little Rock
# 13                             Arizona State University
# 15                             Arizona State University
# 18              California Polytechnic State University
# 19                 California State University-East Bay
# 20                California State University-Fullerton
# 23                California State University-Fullerton
# 24               California State University-Long Beach
# 25           California State University-San Bernardino
# 26                                   Chapman University
# ...
